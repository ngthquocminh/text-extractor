# %%
pip install pyvi
# Out:
# Requirement already satisfied: pyvi in c:\users\nguye\anaconda3\lib\site-packages (0.1)
# Requirement already satisfied: sklearn-crfsuite in c:\users\nguye\anaconda3\lib\site-packages (from pyvi) (0.3.6)
# Requirement already satisfied: scikit-learn in c:\users\nguye\anaconda3\lib\site-packages (from pyvi) (0.23.2)
# Requirement already satisfied: numpy>=1.13.3 in c:\users\nguye\anaconda3\lib\site-packages (from scikit-learn->pyvi) (1.19.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\nguye\anaconda3\lib\site-packages (from scikit-learn->pyvi) (2.1.0)
# Requirement already satisfied: scipy>=0.19.1 in c:\users\nguye\anaconda3\lib\site-packages (from scikit-learn->pyvi) (1.5.2)
# Requirement already satisfied: joblib>=0.11 in c:\users\nguye\anaconda3\lib\site-packages (from scikit-learn->pyvi) (0.17.0)
# Requirement already satisfied: tabulate in c:\users\nguye\anaconda3\lib\site-packages (from sklearn-crfsuite->pyvi) (0.8.9)
# Requirement already satisfied: python-crfsuite>=0.8.3 in c:\users\nguye\anaconda3\lib\site-packages (from sklearn-crfsuite->pyvi) (0.9.7)
# Requirement already satisfied: six in c:\users\nguye\anaconda3\lib\site-packages (from sklearn-crfsuite->pyvi) (1.15.0)
# Requirement already satisfied: tqdm>=2.0 in c:\users\nguye\anaconda3\lib\site-packages (from sklearn-crfsuite->pyvi) (4.50.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install https://github.com/trungtv/vi_spacy/raw/master/packages/vi_spacy_model-0.2.1/dist/vi_spacy_model-0.2.1.tar.gz
# Out:
# Collecting https://github.com/trungtv/vi_spacy/raw/master/packages/vi_spacy_model-0.2.1/dist/vi_spacy_model-0.2.1.tar.gz
#   Using cached https://github.com/trungtv/vi_spacy/raw/master/packages/vi_spacy_model-0.2.1/dist/vi_spacy_model-0.2.1.tar.gz (42.3 MB)
# Requirement already satisfied: spacy>=2.1.4 in c:\users\nguye\anaconda3\lib\site-packages (from vi-spacy-model==0.2.1) (2.2.4)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\nguye\anaconda3\lib\site-packages (from spacy>=2.1.4->vi-spacy-model==0.2.1) (2.24.0)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\nguye\anaconda3\lib\site-packages (from spacy>=2.1.4->vi-spacy-model==0.2.1) (3.0.5)
# Requirement already satisfied: numpy>=1.15.0 in c:\users\nguye\anaconda3\lib\site-packages (from spacy>=2.1.4->vi-spacy-model==0.2.1) (1.19.2)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\nguye\anaconda3\lib\site-packages (from spacy>=2.1.4->vi-spacy-model==0.2.1) (4.50.2)
# Requirement already satisfied: srsly<1.1.0,>=1.0.2 in c:\users\nguye\anaconda3\lib\site-packages (from spacy>=2.1.4->vi-spacy-model==0.2.1) (1.0.5)
# Requirement already satisfied: blis<0.5.0,>=0.4.0 in c:\users\nguye\anaconda3\lib\site-packages (from spacy>=2.1.4->vi-spacy-model==0.2.1) (0.4.1)
# Requirement already satisfied: wasabi<1.1.0,>=0.4.0 in c:\users\nguye\anaconda3\lib\site-packages (from spacy>=2.1.4->vi-spacy-model==0.2.1) (0.8.2)
# Requirement already satisfied: plac<1.2.0,>=0.9.6 in c:\users\nguye\anaconda3\lib\site-packages (from spacy>=2.1.4->vi-spacy-model==0.2.1) (1.1.3)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\nguye\anaconda3\lib\site-packages (from spacy>=2.1.4->vi-spacy-model==0.2.1) (1.0.5)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\nguye\anaconda3\lib\site-packages (from spacy>=2.1.4->vi-spacy-model==0.2.1) (2.0.5)
# Requirement already satisfied: thinc==7.4.0 in c:\users\nguye\anaconda3\lib\site-packages (from spacy>=2.1.4->vi-spacy-model==0.2.1) (7.4.0)
# Requirement already satisfied: setuptools in c:\users\nguye\anaconda3\lib\site-packages (from spacy>=2.1.4->vi-spacy-model==0.2.1) (54.2.0)
# Requirement already satisfied: catalogue<1.1.0,>=0.0.7 in c:\users\nguye\anaconda3\lib\site-packages (from spacy>=2.1.4->vi-spacy-model==0.2.1) (1.0.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in c:\users\nguye\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy>=2.1.4->vi-spacy-model==0.2.1) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\nguye\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy>=2.1.4->vi-spacy-model==0.2.1) (2020.6.20)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\nguye\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy>=2.1.4->vi-spacy-model==0.2.1) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\nguye\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy>=2.1.4->vi-spacy-model==0.2.1) (1.25.11)
# Note: you may need to restart the kernel to use updated packages.

# %%
#!/usr/bin/env python
# coding: utf8
"""Example of training an additional entity type

This script shows how to add a new entity type to an existing pre-trained NER
model. To keep the example short and simple, only four sentences are provided
as examples. In practice, you'll need many more — a few hundred would be a
good start. You will also likely need to mix in examples of other entity
types, which might be obtained by running the entity recognizer over unlabelled
sentences, and adding their annotations to the training set.

The actual training is performed by looping over the examples, and calling
`nlp.entity.update()`. The `update()` method steps through the words of the
input. At each word, it makes a prediction. It then consults the annotations
provided on the GoldParse instance, to see whether it was right. If it was
wrong, it adjusts its weights so that the correct action will score higher
next time.

After training your model, you can save it to a directory. We recommend
wrapping models as Python packages, for ease of deployment.

For more details, see the documentation:
* Training: https://spacy.io/usage/training
* NER: https://spacy.io/usage/linguistic-features#named-entities

Compatible with: spaCy v2.1.0+
Last tested with: v2.1.0
"""
from __future__ import unicode_literals
from __future__ import print_function
import re
import os
import plac
import random
from pathlib import Path
import spacy
import json
import logging

# %%
traindata_file = "traindata.json"
model="vi_spacy_model"
new_model_name="training"
output_dir='/output'
n_iter=20

# %%
# new entity label
LABEL = "COL_NAME"

# training data
# Note: If you're using an existing model, make sure to mix in examples of
# other entity types that spaCy correctly recognized before. Otherwise, your
# model might learn the new type, but "forget" what it previously knew.
# https://explosion.ai/blog/pseudo-rehearsal-catastrophic-forgetting

# training data
# TRAIN_DATA = [
#     ("i study in maria college", {"entities": [(11, 24, LABEL)]}),
#     ("completed graduation from napier university (edinburgh,
#       united kingdom)", {"entities": [(26, 43, LABEL)]}),
#     ("studied in school of continuing and professional studies",
#       {"entities": [(11, 16, LABEL)]}),
#     ("studied at chinese university of hong kong", {"entities":
#       [(11, 29, LABEL)]}),
#     ("studied in University of Strathclyde", {"entities":
#       [(11, 37, LABEL)]}),
# ]


def convert_dataturks_to_spacy(dataturks_JSON_FilePath):
    try:
        training_data = []
        lines = []
        with open(dataturks_JSON_FilePath, 'r', encoding="utf8") as f:
            lines = f.readlines()

        for line in lines:
            data = json.loads(line)

            text = data['content']
            entities = []
            if data['annotation'] is not None:
                for annotation in data['annotation']:
                    # only a single point in text annotation.
                    point = annotation['points'][0]
                    labels = annotation['label']
                    # handle both list of labels or a single label.
                    if not isinstance(labels, list):
                        labels = [labels]

                    for label in labels:
                        # dataturks indices are both inclusive [start, end]
                        # but spacy is not [start, end)
                        entities.append((
                            point['start'],
                            point['end'], # + 1,
                            label
                        ))

            training_data.append((text, {"entities": entities}))
        return training_data
    except Exception:
        logging.exception("Unable to process " + dataturks_JSON_FilePath)
        return None

SPACY_DATA = convert_dataturks_to_spacy(traindata_file)
print(SPACY_DATA)
# Out:
# [('Nhà Đẹp phố Đội Cấn, diện tích 38m2, xây 05 tầng, mặt tiền 4.1m, giá 4.7 t Loại tin Bán nhà riêng Vị trí nhà cách 20m ra mặt ngõ lớn 279 Đội Cấn, đường ô tô tránh, cả ngõ có 5-6 nhà. Tương lai mở rộng ngõ 279 nhà cách ngõ vài mét ( sau này ngõ 279 thành phố Đại Yên) giá trị nhà tăng chóng mặt. Diện tích 38m2, xây 05 tầng, mặt tiền rộng 4,1m, nhà còn rất mới, phù hợp cho việc vừa ở vừa kinh doanh, hoặc cho thuê văn phòng.Nhà chủ nhà tự xây, khung BTCT chắc chắn, thiết kế hiện đại+Tầng 1: 1 Phòng rộng + bếp + vs.+ Tầng 2: P khách + 1 ngủ + vs.+ Tầng 3+4: Mỗi tầng 2 ngủ + vs.+ Tầng 5: P. Thờ + sân phơi.Sổ đỏ chính chủ, pháp lý rõ ràng, sẵn sang giao dịchGiá: 4.7 tỷ có thương lượng cho khách có thiện trí.Liên Hệ: Thanh Tùng: 0912142902. Quý khách gọi ngay để được tư vấn nhiệt tình và xem nhà miễn phí. Nhà mới, ở ngay, ngõ nông, kinh doanh, cho thuê của hàng, văn phòng, Đội Cấn, Ba Đình  Liên hệ:  0912 142 90209121*** hiện số Tên liên hệ: Phan Thanh Tùng Giá 4,7 Tỷ Bán nhà riêng tại Đường Đội Cấn - Phường Đội Cấn -  Ba Đình -  Hà Nôi Điện tích 38 m² Số tầng 5 Số phòng 0 hôm nay 0912142902 Mặt tiền 0 m', {'entities': [(0, 74, 'title'), (75, 97, 'type'), (98, 934, 'description'), (935, 963, 'saller'), (964, 974, 'price'), (975, 1047, 'address'), (1048, 1063, 'area'), (1064, 1073, 'floors'), (1074, 1084, 'rooms'), (1085, 1092, 'date'), (1093, 1103, 'phone'), (1104, 1116, 'front')]}), ('Bán Gấp nhà mặt ngõ Tứ Liên, diện tích 54m2 x 05 tầng, mặt tiền 4m, giá 5,8 tỷ. Loại tin Bán nhà riêng Nhà nằm ở 124 Âu cơ giờ phố Tứ liên, ngõ đẹp nhất Âu Cơ, kinh doanh buôn bán sầm uất. Vị trí đắc địa, vào phố hay ra sân bay đều trong một nốt nhạc, nhà còn rất mới, thiết kế hiện đại, với diện tích rất rộng 54m2, xây 5 tầng, trước nhà đường rộng thẳng tắp, khách mua về là vào ở ngay- Nhà xây dựng được 6 năm, thiết kế tầng 2 phòng, tổng có 7 phòng ngủ. Phía sau có khe thoáng 60 cm hút gió mát rượi, các phòng đều mở cửa sổ, ban công, giếng trời đầy đủ.- Nhà rất phù hợp cho việc ở hoặc đầu tư dòng tiền, cho Tây thuê tuyệt vời, trước chủ cho thuê vui 30tr/ tháng- Sổ phân lô cực đẹp, không chút lỗi lầm. Sẵn sàng giao dịch.- Giá : 5,8 tỷ có thương lượng cho khách có thiện tríLiên Hệ: Thanh Tùng: 0912142902 . Quý khách gọi ngay để được tư vấn nhiệt tình và xem nhà miễn phí  Liên hệ:  0912 142 90209121*** hiện số Tên liên hệ: Phan Thanh Tùng Giá 5,8 Tỷ Bán nhà riêng tại Đường Tứ Liên - Phường Tứ Liên -  Tây Hồ -  Hà Nội Điện tích 54 m² Số tầng 5 Số phòng 0 hôm nay 0912142902 Mặt tiền 0 m', {'entities': [(0, 79, 'title'), (80, 102, 'type'), (103, 920, 'description'), (921, 949, 'saller'), (950, 960, 'price'), (961, 1030, 'address'), (1031, 1046, 'area'), (1047, 1056, 'floors'), (1057, 1067, 'rooms'), (1068, 1075, 'date'), (1076, 1086, 'phone'), (1087, 1099, 'front')]}), ('Mảnh đất vàng để ở và đầu tư chung cư mini, Giảng Võ, diện tích 80m2, Cấp 4, g Loại tin Bán nhà riêng Chỉ 30m ra mặt phố, trước nhà rộng hơn 3m, khu vực khu vực trung tâm giao thông thuận tiện nằm ngay sát ga Cát Linh đường tàu tiện trên cao. Xung quanh rất nhiều tiện ích.+ Mảnh đất này xây hoặc đầu tư đều rất đẹp+ Sổ đỏ chính chủ pháp lý rõ ràng.+ Giá: 5.5 tỷ có thương lượngLiên Hệ: Thanh Tùng : 0912142902. Quý khách gọi ngay để được tư vấn nhiệt tình và xem nhà miễn phí  Liên hệ:  0912 142 90209121*** hiện số Tên liên hệ: Phan Thanh Tùng Giá 5,5 Tỷ Bán nhà riêng tại Phố Giảng Võ - Phường Cát Linh -  Đống Đa -  Hà Nội Điện tích 80 m² Số tầng 1 Số phòng 0 hôm nay 0912142902 Mặt tiền 0 m', {'entities': [(0, 78, 'title'), (79, 101, 'type'), (102, 516, 'description'), (517, 545, 'saller'), (546, 556, 'price'), (557, 628, 'address'), (629, 644, 'area'), (645, 654, 'floors'), (655, 665, 'rooms'), (666, 673, 'date'), (674, 684, 'phone'), (685, 697, 'front')]}), ('Bán Gấp nhà Đội Cấn diện tích 44 m2, xây 05 tầng, mặt tiền rộng 3.4m, giá 4.3 tỷ Loại tin Bán nhà riêng Căn nhà có 102 nằm ở trung tâm Ba Đình được xây 5 tầng , từ tầng 2 đua ra được 46m2. Nhà còn rất mới, khách chi ...

# %%
def trim_entity_spans(data: list) -> list:
    """Removes leading and trailing white spaces from entity spans.

    Args:
        data (list): The data to be cleaned in spaCy JSON format.

    Returns:
        list: The cleaned data.
    """
#     invalid_span_tokens = re.compile(r'\s')

    cleaned_data = data # []
#     for text, annotations in data:
#         entities = annotations['entities']
#         valid_entities = []
# #         print(text)
#         for start, end, label in entities:
#             valid_start = start
#             valid_end = end
#             while valid_start < len(text) and invalid_span_tokens.match(
#                     text[valid_start]):
# #                 print(valid_start, " -> ",text[valid_start])
#                 valid_start += 1

#             while valid_end > 1 and invalid_span_tokens.match(
#                     text[valid_end - 1]):
# #                 print(text[valid_end - 1])
#                 valid_end -= 1
#             valid_entities.append([valid_start, valid_end, label])
#         cleaned_data.append([text, {'entities': valid_entities}])

    return cleaned_data
TRAIN_DATA = trim_entity_spans(SPACY_DATA)
print(TRAIN_DATA)
# Out:
# [('Nhà Đẹp phố Đội Cấn, diện tích 38m2, xây 05 tầng, mặt tiền 4.1m, giá 4.7 t Loại tin Bán nhà riêng Vị trí nhà cách 20m ra mặt ngõ lớn 279 Đội Cấn, đường ô tô tránh, cả ngõ có 5-6 nhà. Tương lai mở rộng ngõ 279 nhà cách ngõ vài mét ( sau này ngõ 279 thành phố Đại Yên) giá trị nhà tăng chóng mặt. Diện tích 38m2, xây 05 tầng, mặt tiền rộng 4,1m, nhà còn rất mới, phù hợp cho việc vừa ở vừa kinh doanh, hoặc cho thuê văn phòng.Nhà chủ nhà tự xây, khung BTCT chắc chắn, thiết kế hiện đại+Tầng 1: 1 Phòng rộng + bếp + vs.+ Tầng 2: P khách + 1 ngủ + vs.+ Tầng 3+4: Mỗi tầng 2 ngủ + vs.+ Tầng 5: P. Thờ + sân phơi.Sổ đỏ chính chủ, pháp lý rõ ràng, sẵn sang giao dịchGiá: 4.7 tỷ có thương lượng cho khách có thiện trí.Liên Hệ: Thanh Tùng: 0912142902. Quý khách gọi ngay để được tư vấn nhiệt tình và xem nhà miễn phí. Nhà mới, ở ngay, ngõ nông, kinh doanh, cho thuê của hàng, văn phòng, Đội Cấn, Ba Đình  Liên hệ:  0912 142 90209121*** hiện số Tên liên hệ: Phan Thanh Tùng Giá 4,7 Tỷ Bán nhà riêng tại Đường Đội Cấn - Phường Đội Cấn -  Ba Đình -  Hà Nôi Điện tích 38 m² Số tầng 5 Số phòng 0 hôm nay 0912142902 Mặt tiền 0 m', {'entities': [(0, 74, 'title'), (75, 97, 'type'), (98, 934, 'description'), (935, 963, 'saller'), (964, 974, 'price'), (975, 1047, 'address'), (1048, 1063, 'area'), (1064, 1073, 'floors'), (1074, 1084, 'rooms'), (1085, 1092, 'date'), (1093, 1103, 'phone'), (1104, 1116, 'front')]}), ('Bán Gấp nhà mặt ngõ Tứ Liên, diện tích 54m2 x 05 tầng, mặt tiền 4m, giá 5,8 tỷ. Loại tin Bán nhà riêng Nhà nằm ở 124 Âu cơ giờ phố Tứ liên, ngõ đẹp nhất Âu Cơ, kinh doanh buôn bán sầm uất. Vị trí đắc địa, vào phố hay ra sân bay đều trong một nốt nhạc, nhà còn rất mới, thiết kế hiện đại, với diện tích rất rộng 54m2, xây 5 tầng, trước nhà đường rộng thẳng tắp, khách mua về là vào ở ngay- Nhà xây dựng được 6 năm, thiết kế tầng 2 phòng, tổng có 7 phòng ngủ. Phía sau có khe thoáng 60 cm hút gió mát rượi, các phòng đều mở cửa sổ, ban công, giếng trời đầy đủ.- Nhà rất phù hợp cho việc ở hoặc đầu tư dòng tiền, cho Tây thuê tuyệt vời, trước chủ cho thuê vui 30tr/ tháng- Sổ phân lô cực đẹp, không chút lỗi lầm. Sẵn sàng giao dịch.- Giá : 5,8 tỷ có thương lượng cho khách có thiện tríLiên Hệ: Thanh Tùng: 0912142902 . Quý khách gọi ngay để được tư vấn nhiệt tình và xem nhà miễn phí  Liên hệ:  0912 142 90209121*** hiện số Tên liên hệ: Phan Thanh Tùng Giá 5,8 Tỷ Bán nhà riêng tại Đường Tứ Liên - Phường Tứ Liên -  Tây Hồ -  Hà Nội Điện tích 54 m² Số tầng 5 Số phòng 0 hôm nay 0912142902 Mặt tiền 0 m', {'entities': [(0, 79, 'title'), (80, 102, 'type'), (103, 920, 'description'), (921, 949, 'saller'), (950, 960, 'price'), (961, 1030, 'address'), (1031, 1046, 'area'), (1047, 1056, 'floors'), (1057, 1067, 'rooms'), (1068, 1075, 'date'), (1076, 1086, 'phone'), (1087, 1099, 'front')]}), ('Mảnh đất vàng để ở và đầu tư chung cư mini, Giảng Võ, diện tích 80m2, Cấp 4, g Loại tin Bán nhà riêng Chỉ 30m ra mặt phố, trước nhà rộng hơn 3m, khu vực khu vực trung tâm giao thông thuận tiện nằm ngay sát ga Cát Linh đường tàu tiện trên cao. Xung quanh rất nhiều tiện ích.+ Mảnh đất này xây hoặc đầu tư đều rất đẹp+ Sổ đỏ chính chủ pháp lý rõ ràng.+ Giá: 5.5 tỷ có thương lượngLiên Hệ: Thanh Tùng : 0912142902. Quý khách gọi ngay để được tư vấn nhiệt tình và xem nhà miễn phí  Liên hệ:  0912 142 90209121*** hiện số Tên liên hệ: Phan Thanh Tùng Giá 5,5 Tỷ Bán nhà riêng tại Phố Giảng Võ - Phường Cát Linh -  Đống Đa -  Hà Nội Điện tích 80 m² Số tầng 1 Số phòng 0 hôm nay 0912142902 Mặt tiền 0 m', {'entities': [(0, 78, 'title'), (79, 101, 'type'), (102, 516, 'description'), (517, 545, 'saller'), (546, 556, 'price'), (557, 628, 'address'), (629, 644, 'area'), (645, 654, 'floors'), (655, 665, 'rooms'), (666, 673, 'date'), (674, 684, 'phone'), (685, 697, 'front')]}), ('Bán Gấp nhà Đội Cấn diện tích 44 m2, xây 05 tầng, mặt tiền rộng 3.4m, giá 4.3 tỷ Loại tin Bán nhà riêng Căn nhà có 102 nằm ở trung tâm Ba Đình được xây 5 tầng , từ tầng 2 đua ra được 46m2. Nhà còn rất mới, khách chi ...

# %%
model="vi_spacy_model"
new_model_name="training"
output_dir='/output'
n_iter=12

"""Set up the pipeline and entity recognizer, and train the new entity."""
random.seed(0)
if model is not None:
    nlp = spacy.load(model)  # load existing spaCy model
    print("Loaded model '%s'" % model)
else:
    nlp = spacy.blank("en")  # create blank Language class
    print("Created blank 'en' model")
# Add entity recognizer to model if it's not in the pipeline
# nlp.create_pipe works for built-ins that are registered with spaCy

if "ner" not in nlp.pipe_names:
    print("Creating new pipe")
    ner = nlp.create_pipe("ner")
    nlp.add_pipe(ner, last=True)
else:
    # otherwise, get it, so we can add labels to it
    ner = nlp.get_pipe("ner")
# Out:
# Loaded model 'vi_spacy_model'
# Creating new pipe

# %%
# add labels
for _, annotations in TRAIN_DATA:
    for ent in annotations.get('entities'):
        ner.add_label(ent[2])

# if model is None or reset_weights:
#     optimizer = nlp.begin_training()
# else:
#     optimizer = nlp.resume_training()
move_names = list(ner.move_names)
# get names of other pipes to disable them during training
other_pipes = [pipe for pipe in nlp.pipe_names if pipe != "ner"]

print(move_names)
print(other_pipes)
# Out:
# ['B-title', 'I-title', 'L-title', 'U-title', 'B-type', 'I-type', 'L-type', 'U-type', 'B-description', 'I-description', 'L-description', 'U-description', 'B-saller', 'I-saller', 'L-saller', 'U-saller', 'B-price', 'I-price', 'L-price', 'U-price', 'B-address', 'I-address', 'L-address', 'U-address', 'B-area', 'I-area', 'L-area', 'U-area', 'B-floors', 'I-floors', 'L-floors', 'U-floors', 'B-rooms', 'I-rooms', 'L-rooms', 'U-rooms', 'B-date', 'I-date', 'L-date', 'U-date', 'B-phone', 'I-phone', 'L-phone', 'U-phone', 'B-front', 'I-front', 'L-front', 'U-front']
# ['tagger', 'parser']

# %%
with nlp.disable_pipes(*other_pipes):  # only train NER
    optimizer = nlp.begin_training()
    # batch up the examples using spaCy's minibatch
    for itn in range(n_iter):
        print("Starting iteration " + str(itn))
        random.shuffle(TRAIN_DATA)
        losses = {}
        for text, annotations in TRAIN_DATA:
            nlp.update(
                [text],  # batch of texts
                [annotations],  # batch of annotations
                drop=0.2,  # dropout - make it harder to memorise data
                sgd=optimizer,  # callable to update weights
                losses=losses)
        print("Losses", losses)
# Out:
# Starting iteration 0
# Losses {'ner': 3412.39817042149}
# Starting iteration 1
# Losses {'ner': 2022.4541246168312}
# Starting iteration 2
# Losses {'ner': 2637.517097651464}
# Starting iteration 3
# Losses {'ner': 1844.8803497555493}
# Starting iteration 4
# Losses {'ner': 2151.6731226158586}
# Starting iteration 5
# Losses {'ner': 2246.0126842284294}
# Starting iteration 6
# Losses {'ner': 2316.0736123384067}
# Starting iteration 7
# Losses {'ner': 1669.1518412698993}
# Starting iteration 8
# Losses {'ner': 1249.046876630287}
# Starting iteration 9
# Losses {'ner': 1186.1702513143277}
# Starting iteration 10
# Losses {'ner': 1079.8076896819957}
# Starting iteration 11
# Losses {'ner': 1311.5960330350003}

# %%
# print("Entities in '%s'" % test_text)
# for ent in doc.ents:
#     ""
#     print(ent.label_, ent.text)

# save model to output directory
output_dir = Path(output_dir)
if not output_dir.exists():
    output_dir.mkdir()
nlp.meta["name"] = new_model_name  # rename model
with nlp.disable_pipes('ner'):
    nlp.to_disk(os.path.join(output_dir, new_model_name))
    print("Saved model to", output_dir)
# Out:
# Saved model to \output

# %%
# test the saved model
test_text = """Nhà Đẹp phố Đội Cấn, diện tích 38m2, xây 05 tầng, mặt tiền 4.1m, giá 4.7 t\nLoại tin Bán nhà riêng\nVị trí nhà cách 20m ra mặt ngõ lớn 279 Đội Cấn, đường ô tô tránh, cả ngõ có 5-6 nhà. Tương lai mở rộng ngõ 279 nhà cách ngõ vài mét ( sau này ngõ 279 thành phố Đại Yên) giá trị nhà tăng chóng mặt. Diện tích 38m2, xây 05 tầng, mặt tiền rộng 4,1m, nhà còn rất mới, phù hợp cho việc vừa ở vừa kinh doanh, hoặc cho thuê văn phòng.Nhà chủ nhà tự xây, khung BTCT chắc chắn, thiết kế hiện đại+Tầng 1: 1 Phòng rộng + bếp + vs.+ Tầng 2: P khách + 1 ngủ + vs.+ Tầng 3+4: Mỗi tầng 2 ngủ + vs.+ Tầng 5: P. Thờ + sân phơi.Sổ đỏ chính chủ, pháp lý rõ ràng, sẵn sang giao dịchGiá: 4.7 tỷ có thương lượng cho khách có thiện trí.Liên Hệ: Thanh Tùng: 0912142902. Quý khách gọi ngay để được tư vấn nhiệt tình và xem nhà miễn phí. Nhà mới, ở ngay, ngõ nông, kinh doanh, cho thuê của hàng, văn phòng, Đội Cấn, Ba Đình  Liên hệ:  0912 142 90209121*** hiện số\nTên liên hệ: Phan Thanh Tùng\nGiá 4,7 Tỷ\nBán nhà riêng tại Đường Đội Cấn - Phường Đội Cấn -  Ba Đình -  Hà Nôi\nĐiện tích 38 m²\nSố tầng 5\nSố phòng 0\nhôm nay\n0912142902\nMặt tiền 0 m"""
test_text = test_text.replace("\n"," ")


test_text = """BÁN GẤP NHÀ PHỐ ĐÀO TẤN, DIỆN TÍCH 50M2, XÂY 4 TẦNG, MẶT TIỀN 5.5M, GIÁ 5.3 Khu Vực: Bán Nhà Riêng Tại Đường Đào Tấn - Phường Cống Vị - Ba Đình - Hà Nội Giá: 5,3 Tỷ  Diện tích: 50 m² hôm nay Thông tin mô tả + Nhà nằm trong ngõ 12 Đào Tấn ô tô tránh có vỉa hè, ngõ thông nhiều phố, nhà cách ô tô đúng 20m, nhà vẫn còn rất mới, khách mua về là vào ở được ngay. + Nhà mới xây được mấy năm nhưng còn rất chắc chắn. Thiết kế nhà bê tông cốt thép chắc chắn, thiết kế hiện đại, nhà bao gồm: phòng khách, bếp, 04 phòng ngủ, phòng thờ, sân phơi + Sổ đỏ chính chủ, pháp lý rõ ràng, sẵn sang giao dịch + Giá 5.3 tỷ, có thương lượng cho khách có thiện trí Liên Hệ: Thanh Tùng BĐS Ba Đình: 0912142902, Quý khách gọi ngay để được tư vấn nhiệt tình và xem nhà miễn phí Cần Bán, ở ngay, ngõ thoáng, nhà còn mới, Ngõ thông, Đào Tấn, Ba Đình Liên hệ: 09121*** hiện số Loại tin rao Bán nhà riêng Pháp lý Sổ Hồng Số phòng 0 Đường vào 0 m Mặt tiền 0 m Số tầng 4 Số toilet 0 Thông tin liên hệ Tên liên hệ: Phan Thanh Tùng Loại tin: Môi giới Địa chỉ: Ba Đình Tỉnh thành Hà Nội Điện thoại: 0912142902 Email: thanhtungks68@gmail.com"""


print("Loading from", output_dir)
nlp2 = spacy.load(os.path.join(output_dir, new_model_name))    
ner = nlp.get_pipe("ner")
nlp2.add_pipe(ner)                  
# Check the classes have loaded back consistently
#     print(nlp2.get_pipe("ner").move_names,"\n",move_names)
#     assert nlp2.get_pipe("ner").move_names == move_names
doc2 = nlp2(test_text)
for ent in doc2.ents:
    print(" > ", ent.label_, ent.text)
# Out:
# Loading from \output
#  >  title BÁN GẤP NHÀ PHỐ ĐÀO TẤN, DIỆN_TÍCH 50M2, XÂY 4 TẦNG, MẶT_TIỀN 5.5M, GIÁ 5.3 Khu_Vực: Bán Nhà_Riêng Tại Đường Đào_Tấn - Phường Cống_Vị - Ba_Đình - Hà_Nội Giá: 5,3 Tỷ Diện_tích: 50 m² hôm_nay Thông_tin mô_tả + Nhà nằm trong ngõ 12 Đào_Tấn ô_tô tránh có vỉa_hè, ngõ thông nhiều phố, nhà cách ô_tô đúng 20m, nhà vẫn còn rất mới, khách mua về là vào ở được ngay. + Nhà mới xây được mấy năm nhưng còn rất chắc_chắn. Thiết_kế nhà bê_tông cốt thép chắc_chắn, thiết_kế hiện_đại, nhà bao_gồm: phòng khách, bếp, 04 phòng ngủ, phòng thờ, sân phơi + Sổ_đỏ chính chủ, pháp_lý rõ_ràng, sẵn sang giao_dịch + Giá 5.3 tỷ, có thương_lượng cho khách có thiện trí Liên_Hệ: Thanh_Tùng BĐS Ba_Đình: 0912142902, Quý_khách gọi ngay để được tư_vấn nhiệt_tình và xem nhà miễn_phí Cần_Bán, ở ngay, ngõ thoáng, nhà còn mới, Ngõ thông, Đào_Tấn, Ba_Đình Liên_hệ: 09121*** hiện số
#  >  type Loại tin rao Bán nhà_riêng
#  >  title Pháp_lý Sổ
#  >  title 0
#  >  title Mặt_tiền 0 m Số tầng 4 Số toilet 0 Thông_tin liên_hệ Tên liên_hệ: Phan_Thanh_Tùng
#  >  type Loại tin: Môi_giới Địa_chỉ: Ba_Đình Tỉnh_thành Hà_Nội Điện_thoại
#  >  title : 0912142902 Email: thanhtungks68@gmail.com
